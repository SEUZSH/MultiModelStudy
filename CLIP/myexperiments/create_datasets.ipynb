# %%
from datasets import load_dataset
from datasets import Dataset, DatasetDict

# 1. 加载图片数据
dataset = load_dataset("imagefolder", data_dir="/mnt/disk1/suhan/STUDY/CLIP/CLIP/myexperiments/images")

# 2. 保存为Hugging Face格式
dataset.save_to_disk("/mnt/disk1/suhan/STUDY/CLIP/CLIP/myexperiments/data/white_dress")
# Out:
# ...
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to /mnt/disk1/suhan/.cache/huggingface/datasets/imagefolder/default-bbd1ef2b11268bd2/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/12 [00:00<?, ? examples/s]
